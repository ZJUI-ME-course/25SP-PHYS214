# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2
import math
# n=math.floor(sqrt(-13.6/(-13.6+12.3)))
# 向下取整
# print(n)

e3=-13.6/9
e2=-13.6/4
e1=-13.6/1
print(e3-e2,e3-e1,e2-e1)
print(4.2)
# Out:
# 1.8888888888888888 12.088888888888889 10.2
# 4.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3
print(2,6)
# Out:
# 2 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.constants import *

l=2.5e-9
q=1.6e-19

e1=(pi*hbar)**2/2/m_e/l**2
e2=(2*pi*hbar)**2/2/m_e/l**2
e3=(3*pi*hbar)**2/2/m_e/l**2
e4=(4*pi*hbar)**2/2/m_e/l**2
e5=(5*pi*hbar)**2/2/m_e/l**2



eground=2*(e1+e2+e3)+e4
print(eground/q)



ex1=2*(e1+e2+e4)+e3 
print(ex1/q)

# ex2=2*(e1+e3+e4)+e2
# print(ex2/q) 


ex3=2*(e1+e2+e3)+e5
print(ex3/q)
# Out:
# 2.650853656984531
# 3.0725803751411607
# 3.1930737231859125

# %%
from scipy.constants import *
