# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1

# E=hc/lamda

# 如果gap大于能量，那么不吸收，透明
# 如果gap小于能量，那么吸收，有这个颜色


print(1240/450)


print(1240/550)


# 一旦有gap都是不导电；。

print('No')
# Out:
# 2.7555555555555555
# 2.2545454545454544
# No

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2

# 加载一个电场，那么电子运动起来p=F*t=m*v
# 注意条件是free 所以没有加前面的vinitial

q=1.6e-19
E=1
t=1e-5
F=E*q
p=F*t
m=9.11e-31
v=p/m
print(v)





# 材料带隙5eV，电场提供的能量才能超过带隙，才能改变电子动量，dertaE=q*E*dertax<5eV,所以动量不变

print(1)
# Out:
# 1756311.7453347968
# 1

# %%
# Out:
# 0.119514105917962
