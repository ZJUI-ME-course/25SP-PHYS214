# %%
from math import *

sin(pi/4)+sin(pi/8)
# Out:
# 1.0897902135516373

# %%
m=9.11e-31
lamda=869.9e-9
c=3e8
h=6.626e-34
sqrt(3*h*lamda/8/c/m)*1e9
# Out:
# 0.8893161910119755

# %%
h/4/pi/150e-12
# Out:
# 3.5152021764229947e-25

# %%
a_2=sqrt(4**2+0.6**2)
b_2=1

1/(1**2+a_2**2)
# Out:
# 0.0576036866359447

# %%
E=0.8*1.6e-19

sqrt(2*m*E)*2*pi/h/1e9
# it is by-x but I don;t know wy
# Out:
# 4.57938975239432

# %%
lamda=500e-9
l=sqrt(3*h*lamda/8/m/c)

print(l*1e9)


lamda=3*lamda/8
print(c/lamda/1e14)
# Out:
# 0.6742276143562224
# 16.0

# %%
0.289*0.256
# Out:
# 0.073984

# %%
v=10
h=6.626e-34
m=9.11e-31

lamda=h/m/v
print(lamda)
# Out:
# 7.273326015367728e-05
# 72733.26015367729

# %%
from sympy import *

a=1.971
x=S('x')
e=2.71
s=2*integrate(e**(-2*a*x),(x,0,oo))

sqrt(1/s)
a=1.971
sqrt(a)
# Out:
# 1.40392307481571

# %%
e=8*1.6e-19

c*sqrt(2*m*e)/e
# Out:
# 357.923699969700

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dertax=285e-12
float(h/4/pi/dertax)
# Out:
# 1.8501064086436816e-25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a_2=3**2+0.3**2
b_2=2**2

a_2/(a_2+b_2)
# Out:
# 0.6944232238349886

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
h=6.626e-34
m=9.11e-31


E=0.8*1.6e-19 
float(sqrt(2*m*E)/h*2*pi)
# Out:
# 4579389752.39432

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lamda=500e-9
l=sqrt(3*h*lamda/8/m/c)
print(l*1e9)
c=3e8

c/1500e-9*8/1e14
# Out:
# 0.674227614356222
# 16.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v=5
lamda=h/m/v

print(lamda/1e-3)
# Out:
# 0.14546652030735457

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=1.932
sqrt(a)
# Out:
# 1.38996402831152

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 第二题的意思是分别让两个粒子投在屏幕上，希望alpha1-alpha2变小，所以需要lamda_photon变小，或者lamda——electron变大

# %%
e=8*1.6e-19

r=c/e*sqrt(2*m*e)
print(r)
# Out:
# 357.923699969700

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.233*0.163*6
# Out:
# 0.22787400000000002

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
float(-sin(pi/4)-sin(pi/3))
# Out:
# -1.5731321849709863

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lamda=53.7e-9
sqrt(3*h*lamda/8/m/c)*1e9
# Out:
# 0.220957463956654
