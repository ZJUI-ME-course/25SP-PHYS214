# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 12.258064516129032

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 
from sympy import *
L=31e3
y=2


theta=y/L
lamda=550e-9
d=1.22*lamda/sin(theta)

print(d)
# Out:
# 0.0104005000072151

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
lamda=1e-6
h=6.626e-34
c=3e8

e=1.6e-19
E=h*c/lamda/e

print(E)
# Out:
# 1.2423750000000002

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3ev

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d=1.5e-3


h=6.636e-34
m=9.11e-31
v=10



lamda=h/(m*v)
# 看清是暗条纹
(lamda/2)/d
# Out:
# 0.02428100987925356

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *

fai1=1.5
fai2=0.7


a1=sqrt((cos(fai1)+cos(fai2))**2+(sin(fai1)+sin(fai2))**2)
a2=5

a1**2/(a1**2+a2**2)
# Out:
# 0.119514105917962

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 方向就是整体换方向

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 那得看清是吸收 还是放出
# Out:
# 266.6666666666667

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 没问题

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f=1e17
c=3e8
lamda=c/f
h=6.626e-34
p=h/lamda

m2=3.44e-25
v2=p/m2

print(v2)
# Out:
# 0.6420542635658916

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
theta=1/180*pi
f=260e9
c=3e8

lamda=c/f

d=1.22*lamda/theta
print(d.evalf())
# Out:
# 0.0806548280838005

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y=0.309e-3
L=0.96
d=12e-6
v=2.967


lamda=y/L*d

p=h/lamda

m=p/v
print(m)
# Out:
# 5.78183099313593e-26
